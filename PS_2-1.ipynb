# %% [markdown]
# # Homework 2
#
# Due January 24 11:59 PM on canvas
#
# ## Part A: Algorithms and statistics (40 points)
#
# For Part A, you'll be submitting a separate PDF of your work. You do not need to supply your answers to Part A within this Jupyter notebook. Please label your pdf with your first and last name before submitting (i.e. "GS559_PS2_Maddy_Duran.pdf")

# %% [markdown]
# #### 1. (20 points)
#
# Score this alignment using a linear gap penalty of -4 and the substitution matrix provided. Please show your arithmetic!
#
#
# Substitution matrix:
#
# |           | **A**     | **C**     | **G**     | **T**     |
# | :-------  | :-------: | :-------: | :-------: | :-------: |
# | **A**     |   10      |   -5      |    0      |   -5      |
# | **C**     |   -5      |   10      |   -5      |    0      |
# | **G**     |    0      |   -5      |   10      |   -5      |
# | **T**     |   -5      |    0      |   -5      |   10      |
#
#
# <br>
#
# Find the optimal (a) global and (b) local alignment(s) between the following sequences. Write down the score and dynamic programming matrix for each.
# <br>
#
# `Sequence 1: ACTCA`
# <br>
# `Sequence 2: CGCTC`

# %% [markdown]
# #### 2. (20 points)
# Use the dynamic programming matrix below to answer the following questions. Note that the letter code J indicates leucine or isoleucine. For the purposes of this problem, you can treat J as if it were a regular amino acid.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (A) Was this DP matrix generated by the Smith-Waterman or Needleman-Wunsch algorithm? How do you know? *(5 points)*
#
#
# (B) For this DP matrix, is the gap penalty linear or affine? Give the value(s). *(5 points)*
#
# (C) Draw an empty amino acid substitution matrix, and fill in as many values as you can, based on the above DP matrix. Note that it is impossible to fill the entire matrix from the information we have provided. *(10 points)*

# %% [markdown]
# ## PART B. Programming (60 POINTS)
#
# **For Part B, you'll be editing this Jupyter notebook directly.** Please label your notebook file with your first and last name before submitting (i.e. "GS559_PS2_Maddy_Duran.ipynb")
#
# Each question in Part B requires you to define a function that takes in the given argument and produces the specified output.
#
# #### General reminders and advice:
# - Test your code and make sure the outputs match the expected output. You can use the provided examples for testing, but be aware that your functions should work for any valid input.
# - For the purposes of this class, don’t Google solutions - try to do the homework using what was taught in class. Generally, Google is your friend when it comes to coding, but the early concepts being taught in this class are important to fully understand.
# - **<ins>Please do not import any packages for this assignment.</ins>** There may exist packages which will do some of the tasks below for you, but the point of these exercises is to become comfortable using Python's base functions. All exercises can be completed with only the concepts we have covered in class.

# %% [markdown]
# #### 3. (15 points)
#
# GIVEN: an input file to copy and a name for the copied file<br>
# RETURN: the input file copied to a new file named with the filename
#
# ```python
# > copy_file("seq1.txt", "seq2.txt")
# 'File copying is complete!'
# ```
# where 'seq1.txt' is a file containing the text 'GATCCAT' and 'seq2.txt' does not exist in the directory until the program is run. Please make sure your code works (copies the whole file) even if the input file is more than one line long!

# %%
def copy_file():
    """
    Define your function here for question 3
    """

# %% [markdown]
# #### 4. (15 points)
#
# GIVEN: a file with multiple lines <br>
# RETURN: the lines of the file in reverse order
#
# ```python
# > reverse_lines("three-lines.txt")
# This is the third line.
# This is the second line.
# This is the first line.
# ```
#
# Note: your code should be able to perform this task on a file of any length (make sure it's not specific to just a three line input).

# %%
def reverse_lines():
    """
    Define your function here for question 4
    """

# %% [markdown]
# #### 5.	(15 points)
# GIVEN: a number and a format, where the format is either integer, real or scientific.<br>
# RETURN: the given number in the requested format, AND print an error if an invalid format string is provided.
#
# ```python
# > format_number(3.14159, "integer")
# 3
# > format_number(3.14159, "real")
# 3.14159
# > format_number(3.14159, "scientific")
# 3.141590e+00
# > format_number(3.14159, "foo")
# Invalid format: foo
# ```

# %%
def format_number(): 
    """
    Define your function here for question 5
    """

# %% [markdown]
# #### 6.  (15 points)
# GIVEN: two fasta files and a filename<br>
# RETURN: a single file containing all the information in the two inputs
#
# ```python
# > combine_fasta("first.fasta", "second.fasta", "concat.fasta")
# 'Fasta concatenation complete!'
# ```

# %%
def combine_fasta(): 
    """
    Define your function here for question 6
    """
